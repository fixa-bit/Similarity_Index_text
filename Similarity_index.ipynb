# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# %%
cd '/content/gdrive/My Drive/newdata'
# Out:
# /content/gdrive/My Drive/newdata

# %%
pip install pyxDamerauLevenshtein
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pyxDamerauLevenshtein: filename=pyxDamerauLevenshtein-1.7.1-cp310-cp310-linux_x86_64.whl size=70669 sha256=b22dd5afd5216bfdcf304faab49a7fc0e2ab75268474b80a44959ea0b4377f4e
#   Stored in directory: /root/.cache/pip/wheels/a7/6f/29/3c4490c70e8dde5a58752c4e63aaf46df9d6a24861d8a06c08
# Successfully built pyxDamerauLevenshtein
# ERROR: Operation cancelled by user

# %%
temp = open('test1.txt','r').read().split('\n')
total=0
equal=0
i=0
index_sub=[]
temp = list(filter(None, temp))#to remove any empty list of strings

temp[0]
for line in temp:
      if i==0:

        #word_l=[word_lx]

        word_lx=line.split(' ')
        word_l=[word_lx]




        i=i+1
      else:
        word_lx=line.split(' ')
        word_l.append(word_lx)


        #word_l=[word_lx]
        i=i+1

# %%
org = open("test_data.txt",'r').read().split('\n')

i=0
temp2 = list(filter(None, org))#to remove any empty list of strings

temp2[0]
for line in temp2:
      if i==0:

        #word_l=[word_lx]

        wordorg_lx=line.split(' ')
        wordorg_l=[wordorg_lx]




        i=i+1
      else:
        wordorg_lx=line.split(' ')
        wordorg_l.append(wordorg_lx)


        #word_l=[word_lx]
        i=i+1

# %%
# word_l.len()
print(len(wordorg_l))
len(word_l)
# Out:
# 563
# 563

# %%
print((wordorg_l[0]))
print(word_l[0])
# Out:
# ['کانفرنس/سیمینار،', 'آڈیٹوریم', 'کی', 'ادائیگی،', 'دفتر', 'کی', 'بلڈنگ', 'کا', 'کرایہ،', 'میڈیکل', 'الاونسز', 'رہائشی', 'مکانوں', 'کے', 'کرائے', 'میڈیکل', 'بلوں', 'کے', 'اخراجات', 'کی', 'نشاندہی']
# ['کانفرنس/سیمینار،', 'آڈیٹوریم', 'کی', 'ادائیگی،', 'دفتر', 'کی', 'بلڈنگ', 'کا', 'کرایہ،', 'میڈیکلال', 'اونسزرہائشی', 'مکانوں', 'کے', 'کرائے', 'میڈیکل', 'بلوں', 'کے', 'اخراجات', 'کی', 'نشاندہی']

# %%
print((wordorg_l[1]))
print(word_l[1])
# Out:
# ['متعلقہ', 'وزارتوں', 'کی', 'سطح', 'پر', 'MTBF', 'پروگرام', 'کے', 'رہنما', 'اصول', 'اور', 'MTBF', 'پروگرام', 'کے', 'تحت', 'بجٹ', 'کال', 'سرکلر', 'جاری', 'کیا', 'گياہے۔']
# ['متعلقہ', 'وزارتوں', 'کی', 'سطح', 'پر', 'MTBF', 'پروگرام', 'کے', 'رہنما', 'اصول', 'اور', 'MTBF', 'پروگرام', 'کے', 'تحت', 'بجٹ', 'کال', 'سرکلر', 'جاری', 'کیا', 'گيا', 'ہے۔']

# %%
#test1
i=0
res=0
for test_item in wordorg_l:
    test_list1=wordorg_l[i]
    test_list2=word_l[i]


    matches = [x for x in wordorg_l[i] if x in word_l[i]]
    xx=len(matches)
    total=len(wordorg_l[i])
    resnew = xx/ total * 100
    # print("matches="+str(xx))
    print("length of line %s"%i+"="+str(len(wordorg_l[i]))+" Total mactching words :"+str(xx)+" Percentage similarity for current line : " + str(resnew))
    #res = len(set(test_list1) and set(test_list2)) / float(len(set(test_list1) or set(test_list2))) * 100
    res=res+resnew

    # printing result

    i=i+1
    #print(i)
    # print(res)
    # print("resnew = "+str(resnew)+"res = "+str(res))


print(res)
print(res/i)
# Out:
# length of line 0=21 Total mactching words :16 Percentage similarity for current line : 76.19047619047619
# length of line 1=21 Total mactching words :20 Percentage similarity for current line : 95.23809523809523
# length of line 2=22 Total mactching words :20 Percentage similarity for current line : 90.9090909090909
# length of line 3=24 Total mactching words :24 Percentage similarity for current line : 100.0
# length of line 4=23 Total mactching words :18 Percentage similarity for current line : 78.26086956521739
# length of line 5=23 Total mactching words :22 Percentage similarity for current line : 95.65217391304348
# length of line 6=30 Total mactching words :29 Percentage similarity for current line : 96.66666666666667
# length of line 7=31 Total mactching words :30 Percentage similarity for current line : 96.7741935483871
# length of line 8=22 Total mactching words :21 Percentage similarity for current line : 95.45454545454545
# ...

# %%
#test2
i=0
res=0
for test_item in wordorg_l:
    test_list1=wordorg_l[i]
    test_list2=word_l[i]


    matches = [x for x in wordorg_l[i] if x in word_l[i]]
    xx=len(matches)
    total=len(wordorg_l[i])
    resnew = xx/ total * 100
    # print("matches="+str(xx))
    print("length of line %s"%i+"="+str(len(wordorg_l[i]))+" Total mactching words :"+str(xx)+" Percentage similarity for current line : " + str(resnew))
    #res = len(set(test_list1) and set(test_list2)) / float(len(set(test_list1) or set(test_list2))) * 100
    res=res+resnew

    # printing result

    i=i+1
    #print(i)
    # print(res)
    # print("resnew = "+str(resnew)+"res = "+str(res))


print(res)
print(res/i)
# Out:
# length of line 0=21 Total mactching words :19 Percentage similarity for current line : 90.47619047619048
# length of line 1=21 Total mactching words :20 Percentage similarity for current line : 95.23809523809523
# length of line 2=22 Total mactching words :20 Percentage similarity for current line : 90.9090909090909
# length of line 3=24 Total mactching words :23 Percentage similarity for current line : 95.83333333333334
# length of line 4=23 Total mactching words :17 Percentage similarity for current line : 73.91304347826086
# length of line 5=23 Total mactching words :22 Percentage similarity for current line : 95.65217391304348
# length of line 6=30 Total mactching words :29 Percentage similarity for current line : 96.66666666666667
# length of line 7=31 Total mactching words :28 Percentage similarity for current line : 90.32258064516128
# length of line 8=22 Total mactching words :21 Percentage similarity for current line : 95.45454545454545
# ...

# %%
#test3
i=0
res=0
for test_item in wordorg_l:
    test_list1=wordorg_l[i]
    test_list2=word_l[i]


    matches = [x for x in wordorg_l[i] if x in word_l[i]]
    xx=len(matches)
    total=len(wordorg_l[i])
    resnew = xx/ total * 100
    # print("matches="+str(xx))
    print("length of line %s"%i+"="+str(len(wordorg_l[i]))+" Total mactching words :"+str(xx)+" Percentage similarity for current line : " + str(resnew))
    #res = len(set(test_list1) and set(test_list2)) / float(len(set(test_list1) or set(test_list2))) * 100
    res=res+resnew

    # printing result

    i=i+1
    #print(i)
    # print(res)
    # print("resnew = "+str(resnew)+"res = "+str(res))


print(res)
print(res/i)
# Out:
# length of line 0=21 Total mactching words :19 Percentage similarity for current line : 90.47619047619048
# length of line 1=21 Total mactching words :20 Percentage similarity for current line : 95.23809523809523
# length of line 2=22 Total mactching words :20 Percentage similarity for current line : 90.9090909090909
# length of line 3=24 Total mactching words :24 Percentage similarity for current line : 100.0
# length of line 4=23 Total mactching words :17 Percentage similarity for current line : 73.91304347826086
# length of line 5=23 Total mactching words :22 Percentage similarity for current line : 95.65217391304348
# length of line 6=30 Total mactching words :29 Percentage similarity for current line : 96.66666666666667
# length of line 7=31 Total mactching words :30 Percentage similarity for current line : 96.7741935483871
# length of line 8=22 Total mactching words :21 Percentage similarity for current line : 95.45454545454545
# ...
